# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
from citipy import citipy

# %%
# Create 2000 random latitude and longitude combinations.
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | filotion
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | coolum beach
# Processing Record 5 of Set 1 | hay river
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | nome
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | nizwa
# Processing Record 12 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 1 | manokwari
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | ixtapa
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | lobnya
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | prince rupert
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | grand bank
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | la ronge
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | bardiyah
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | kijang
# Processing Record 40 of Set 1 | raudeberg
# Processing Record 41 of Set 1 | acandi
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | thohoyandou
# Processing Record 44 of Set 1 | callaway
# Processing Record 45 of Set 1 | bonavista
# Processing Record 46 of Set 1 | devils lake
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | ca mau
# Processing Record 50 of Set 1 | guerrero negro
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | dhidhdhoo
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | sao felix do xingu
# Processing Record 5 of Set 2 | avera
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | maputo
# Processing Record 8 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 9 of Set 2 | moron
# Processing Record 10 of Set 2 | barcelona
# Processing Record 11 of Set 2 | namatanai
# Processing Record 12 of Set 2 | provideniya
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | jiwani
# Processing Record 15 of Set 2 | biak
# Processing Record 16 of Set 2 | rocha
# Processing Record 17 of Set 2 | beringovskiy
# Processing Record 18 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 2 | touba
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | bogorodskoye
# Processing Record 25 of Set 2 | talcahuano
# Processing Record 26 of Set 2 | kutum
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | papayal
# Processing Record 29 of Set 2 | tabuk
# Processing Record 30 of Set 2 | sandusky
# Processing Record 31 of Set 2 | baykit
# Processing Record 32 of Set 2 | yeniseysk
# Processing Record 33 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | peace river
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | san ciro de acosta
# Processing Record 38 of Set 2 | cherskiy
# Processing Record 39 of Set 2 | jiuquan
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | yugorsk
# Processing Record 44 of Set 2 | severo-kurilsk
# Processing Record 45 of Set 2 | talaya
# Processing Record 46 of Set 2 | mirnyy
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | kindu
# Processing Record 49 of Set 2 | tanete
# Processing Record 50 of Set 2 | temir
# Processing Record 1 of Set 3 | padang
# Processing Record 2 of Set 3 | waiuku
# Processing Record 3 of Set 3 | lata
# Processing Record 4 of Set 3 | adre
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | odesskoye
# Processing Record 7 of Set 3 | suba
# Processing Record 8 of Set 3 | codrington
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | clyde river
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 3 | iberia
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | aban
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | chernyshevskiy
# Processing Record 19 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 3 | pokhara
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | ust-kalmanka
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | thanh hoa
# Processing Record 26 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | maralal
# Processing Record 30 of Set 3 | roma
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | simbahan
# Processing Record 35 of Set 3 | imelda
# Processing Record 36 of Set 3 | ostrovnoy
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | aklavik
# Processing Record 39 of Set 3 | tanout
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | brigantine
# Processing Record 42 of Set 3 | ballina
# Processing Record 43 of Set 3 | honningsvag
# Processing Record 44 of Set 3 | poso
# Processing Record 45 of Set 3 | urengoy
# Processing Record 46 of Set 3 | faanui
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | saint anthony
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | bushehr
# Processing Record 2 of Set 4 | balotra
# Processing Record 3 of Set 4 | yerbogachen
# Processing Record 4 of Set 4 | toora-khem
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | yaan
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | cerro largo
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | boromlya
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | kuhdasht
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | los alamos
# Processing Record 17 of Set 4 | vertientes
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | zhangjiakou
# Processing Record 20 of Set 4 | bluff
# Processing Record 21 of Set 4 | lagoa
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | baghdad
# Processing Record 24 of Set 4 | coquimbo
# Processing Record 25 of Set 4 | puerto escondido
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | soyo
# Processing Record 28 of Set 4 | henties bay
# Processing Record 29 of Set 4 | manggar
# Processing Record 30 of Set 4 | yellowknife
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | playas
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | alamosa
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | mogok
# Processing Record 37 of Set 4 | leh
# Processing Record 38 of Set 4 | dalvik
# Processing Record 39 of Set 4 | gedo
# Processing Record 40 of Set 4 | harnosand
# Processing Record 41 of Set 4 | arlit
# Processing Record 42 of Set 4 | biograd na moru
# Processing Record 43 of Set 4 | kidal
# Processing Record 44 of Set 4 | stirion
# Processing Record 45 of Set 4 | vyartsilya
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | ambovombe
# Processing Record 48 of Set 4 | cockburn town
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | kamaishi
# Processing Record 1 of Set 5 | nouakchott
# Processing Record 2 of Set 5 | monkey bay
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | gogrial
# Processing Record 5 of Set 5 | mafinga
# Processing Record 6 of Set 5 | emerald
# Processing Record 7 of Set 5 | rawson
# Processing Record 8 of Set 5 | traverse city
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | asau
# Processing Record 11 of Set 5 | yining
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 16 of Set 5 | taoudenni
# Processing Record 17 of Set 5 | alice springs
# Processing Record 18 of Set 5 | milkovo
# Processing Record 19 of Set 5 | vostok
# Processing Record 20 of Set 5 | gomel
# Processing Record 21 of Set 5 | mering
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | hambantota
# Processing Record 24 of Set 5 | kansanshi
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | tucupita
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | varhaug
# Processing Record 31 of Set 5 | mackay
# Processing Record 32 of Set 5 | yar-sale
# Processing Record 33 of Set 5 | richards bay
# Processing Record 34 of Set 5 | banda aceh
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 5 | poum
# Processing Record 38 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 39 of Set 5 | santo antonio do ica
# Processing Record 40 of Set 5 | ossora
# Processing Record 41 of Set 5 | maniitsoq
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | giresun
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | trairi
# Processing Record 48 of Set 5 | khatanga
# Processing Record 49 of Set 5 | tambacounda
# Processing Record 50 of Set 5 | mindelo
# Processing Record 1 of Set 6 | byron bay
# Processing Record 2 of Set 6 | shahreza
# Processing Record 3 of Set 6 | imbituba
# Processing Record 4 of Set 6 | sola
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | ayan
# Processing Record 7 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 6 | newport
# Processing Record 10 of Set 6 | diebougou
# Processing Record 11 of Set 6 | brawley
# Processing Record 12 of Set 6 | penzance
# Processing Record 13 of Set 6 | shirokiy
# Processing Record 14 of Set 6 | takoradi
# Processing Record 15 of Set 6 | port hedland
# Processing Record 16 of Set 6 | talnakh
# Processing Record 17 of Set 6 | maniwaki
# Processing Record 18 of Set 6 | aykhal
# Processing Record 19 of Set 6 | nara
# Processing Record 20 of Set 6 | artyom
# Processing Record 21 of Set 6 | mareeba
# Processing Record 22 of Set 6 | kashi
# Processing Record 23 of Set 6 | rudbar
# Processing Record 24 of Set 6 | paratinga
# Processing Record 25 of Set 6 | torbay
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | jiancheng
# Processing Record 28 of Set 6 | aripuana
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | daru
# Processing Record 31 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 6 | amparafaravola
# Processing Record 33 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 6 | teya
# Processing Record 35 of Set 6 | flinders
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | ojdula
# Processing Record 40 of Set 6 | dongsheng
# Processing Record 41 of Set 6 | misratah
# Processing Record 42 of Set 6 | sorong
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | blackwater
# Processing Record 45 of Set 6 | domoni
# Processing Record 46 of Set 6 | lixourion
# Processing Record 47 of Set 6 | salinopolis
# Processing Record 48 of Set 6 | ollioules
# Processing Record 49 of Set 6 | banjar
# Processing Record 50 of Set 6 | luderitz
# Processing Record 1 of Set 7 | bilma
# Processing Record 2 of Set 7 | hithadhoo
# Processing Record 3 of Set 7 | pullman
# Processing Record 4 of Set 7 | kaeo
# Processing Record 5 of Set 7 | puerto ayora
# Processing Record 6 of Set 7 | mount isa
# Processing Record 7 of Set 7 | bulgan
# Processing Record 8 of Set 7 | kirakira
# Processing Record 9 of Set 7 | congonhas
# Processing Record 10 of Set 7 | ndioum
# Processing Record 11 of Set 7 | vila velha
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | kamenka
# Processing Record 14 of Set 7 | sur
# Processing Record 15 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 7 | rudnichnyy
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | fort nelson
# Processing Record 19 of Set 7 | suamico
# Processing Record 20 of Set 7 | stromness
# Processing Record 21 of Set 7 | meiganga
# Processing Record 22 of Set 7 | kaoma
# Processing Record 23 of Set 7 | zhezkazgan
# Processing Record 24 of Set 7 | ust-shonosha
# Processing Record 25 of Set 7 | wawina
# Processing Record 26 of Set 7 | nukus
# Processing Record 27 of Set 7 | chokurdakh
# Processing Record 28 of Set 7 | laguna
# Processing Record 29 of Set 7 | pangody
# Processing Record 30 of Set 7 | aleksandrov gay
# Processing Record 31 of Set 7 | guilin
# Processing Record 32 of Set 7 | hobyo
# Processing Record 33 of Set 7 | sao joao da barra
# Processing Record 34 of Set 7 | chipinge
# Processing Record 35 of Set 7 | nikki
# Processing Record 36 of Set 7 | lac-megantic
# Processing Record 37 of Set 7 | komsomolets
# Processing Record 38 of Set 7 | yola
# Processing Record 39 of Set 7 | magadan
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | chimbote
# Processing Record 42 of Set 7 | bauta
# Processing Record 43 of Set 7 | ushtobe
# Processing Record 44 of Set 7 | kismayo
# Processing Record 45 of Set 7 | pilar
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | altamont
# Processing Record 48 of Set 7 | suntar
# Processing Record 49 of Set 7 | beibei
# Processing Record 50 of Set 7 | lugovoy
# Processing Record 1 of Set 8 | vilhena
# Processing Record 2 of Set 8 | cayeli
# Processing Record 3 of Set 8 | muravlenko
# Processing Record 4 of Set 8 | buraydah
# Processing Record 5 of Set 8 | areosa
# Processing Record 6 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | tambura
# Processing Record 9 of Set 8 | tekirdag
# Processing Record 10 of Set 8 | tromso
# Processing Record 11 of Set 8 | tshela
# Processing Record 12 of Set 8 | taloda
# Processing Record 13 of Set 8 | pombas
# Processing Record 14 of Set 8 | oktyabrskoye
# Processing Record 15 of Set 8 | springbok
# Processing Record 16 of Set 8 | trois-rivieres
# Processing Record 17 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 8 | la macarena
# Processing Record 19 of Set 8 | custoias
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 8 | presidencia roque saenz pena
# Processing Record 25 of Set 8 | hami
# Processing Record 26 of Set 8 | ormara
# Processing Record 27 of Set 8 | praia da vitoria
# Processing Record 28 of Set 8 | half moon bay
# Processing Record 29 of Set 8 | suoyarvi
# Processing Record 30 of Set 8 | ilulissat
# Processing Record 31 of Set 8 | rio gallegos
# Processing Record 32 of Set 8 | tautira
# Processing Record 33 of Set 8 | maldonado
# Processing Record 34 of Set 8 | samfya
# Processing Record 35 of Set 8 | limon
# Processing Record 36 of Set 8 | la romana
# Processing Record 37 of Set 8 | tabou
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | zelenoborsk
# Processing Record 40 of Set 8 | de aar
# Processing Record 41 of Set 8 | beloha
# Processing Record 42 of Set 8 | general roca
# Processing Record 43 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 8 | sokoni
# Processing Record 45 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 8 | cuamba
# Processing Record 47 of Set 8 | koster
# Processing Record 48 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 8 | beloye
# Processing Record 50 of Set 8 | college
# Processing Record 1 of Set 9 | turiacu
# Processing Record 2 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 9 | qasigiannguit
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | salinas
# Processing Record 6 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 9 | denpasar
# Processing Record 8 of Set 9 | beaverlodge
# Processing Record 9 of Set 9 | narasannapeta
# Processing Record 10 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 9 | goderich
# Processing Record 12 of Set 9 | ryomgard
# Processing Record 13 of Set 9 | kapoeta
# Processing Record 14 of Set 9 | lavrentiya
# Processing Record 15 of Set 9 | faya
# Processing Record 16 of Set 9 | pangnirtung
# Processing Record 17 of Set 9 | udachnyy
# Processing Record 18 of Set 9 | pecos
# Processing Record 19 of Set 9 | muisne
# Processing Record 20 of Set 9 | batagay-alyta
# Processing Record 21 of Set 9 | hualmay
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | mishan
# Processing Record 24 of Set 9 | qiongshan
# Processing Record 25 of Set 9 | anjiang
# Processing Record 26 of Set 9 | kamennogorsk
# Processing Record 27 of Set 9 | noyabrsk
# Processing Record 28 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 29 of Set 9 | coos bay
# Processing Record 30 of Set 9 | polovinnoye
# Processing Record 31 of Set 9 | alpena
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | hue
# Processing Record 34 of Set 9 | sinnamary
# Processing Record 35 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 9 | christchurch
# Processing Record 37 of Set 9 | albanel
# Processing Record 38 of Set 9 | cap malheureux
# Processing Record 39 of Set 9 | la asuncion
# Processing Record 40 of Set 9 | punta alta
# Processing Record 41 of Set 9 | camacha
# Processing Record 42 of Set 9 | fare
# Processing Record 43 of Set 9 | bacolod
# Processing Record 44 of Set 9 | caucaia
# Processing Record 45 of Set 9 | kumluca
# Processing Record 46 of Set 9 | liverpool
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | oluta
# Processing Record 49 of Set 9 | blytheville
# Processing Record 50 of Set 9 | aguimes
# Processing Record 1 of Set 10 | ulundi
# Processing Record 2 of Set 10 | vanderhoof
# Processing Record 3 of Set 10 | luanda
# Processing Record 4 of Set 10 | abu samrah
# Processing Record 5 of Set 10 | mayahi
# Processing Record 6 of Set 10 | cajuru
# Processing Record 7 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 10 | atasu
# Processing Record 9 of Set 10 | pozo colorado
# Processing Record 10 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 10 | port hawkesbury
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | am timan
# Processing Record 14 of Set 10 | aksu
# Processing Record 15 of Set 10 | ambon
# Processing Record 16 of Set 10 | tuatapere
# Processing Record 17 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 10 | changqing
# Processing Record 19 of Set 10 | bani
# Processing Record 20 of Set 10 | zhanaozen
# Processing Record 21 of Set 10 | srednekolymsk
# Processing Record 22 of Set 10 | axim
# Processing Record 23 of Set 10 | springdale
# Processing Record 24 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 10 | bloomington
# Processing Record 26 of Set 10 | adrar
# Processing Record 27 of Set 10 | charters towers
# Processing Record 28 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 10 | zhicheng
# Processing Record 30 of Set 10 | boralday
# Processing Record 31 of Set 10 | kongolo
# Processing Record 32 of Set 10 | iringa
# Processing Record 33 of Set 10 | majene
# Processing Record 34 of Set 10 | korem
# Processing Record 35 of Set 10 | north bend
# Processing Record 36 of Set 10 | lianzhou
# Processing Record 37 of Set 10 | dali
# Processing Record 38 of Set 10 | yicheng
# Processing Record 39 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 10 | brae
# Processing Record 41 of Set 10 | fortuna
# Processing Record 42 of Set 10 | burgos
# Processing Record 43 of Set 10 | tiksi
# Processing Record 44 of Set 10 | ruwi
# Processing Record 45 of Set 10 | soc trang
# Processing Record 46 of Set 10 | matriz de camaragibe
# Processing Record 47 of Set 10 | lovozero
# Processing Record 48 of Set 10 | konjic
# Processing Record 49 of Set 10 | mandaguacu
# Processing Record 50 of Set 10 | melfort
# Processing Record 1 of Set 11 | cidreira
# Processing Record 2 of Set 11 | ust-tsilma
# Processing Record 3 of Set 11 | excelsior springs
# Processing Record 4 of Set 11 | gharb
# City not found. Skipping...
# Processing Record 5 of Set 11 | eureka
# Processing Record 6 of Set 11 | predivinsk
# Processing Record 7 of Set 11 | payo
# Processing Record 8 of Set 11 | severo-yeniseyskiy
# Processing Record 9 of Set 11 | pontian kecil
# Processing Record 10 of Set 11 | mbuji-mayi
# Processing Record 11 of Set 11 | nampula
# Processing Record 12 of Set 11 | yunyang
# Processing Record 13 of Set 11 | bessonovka
# Processing Record 14 of Set 11 | grasse
# Processing Record 15 of Set 11 | santiago
# Processing Record 16 of Set 11 | mangrol
# Processing Record 17 of Set 11 | borama
# City not found. Skipping...
# Processing Record 18 of Set 11 | mehamn
# Processing Record 19 of Set 11 | el alto
# Processing Record 20 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 11 | rust
# Processing Record 22 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 25 of Set 11 | bloemfontein
# Processing Record 26 of Set 11 | oreoi
# Processing Record 27 of Set 11 | doha
# Processing Record 28 of Set 11 | inhambane
# Processing Record 29 of Set 11 | mujiayingzi
# Processing Record 30 of Set 11 | paamiut
# Processing Record 31 of Set 11 | san fernando
# Processing Record 32 of Set 11 | maracacume
# Processing Record 33 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 11 | moree
# Processing Record 35 of Set 11 | asuncion
# Processing Record 36 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 11 | clyde
# Processing Record 38 of Set 11 | belyy yar
# Processing Record 39 of Set 11 | elesbao veloso
# Processing Record 40 of Set 11 | vanimo
# Processing Record 41 of Set 11 | tukrah
# Processing Record 42 of Set 11 | ambatolampy
# Processing Record 43 of Set 11 | sabang
# Processing Record 44 of Set 11 | bellview
# Processing Record 45 of Set 11 | novyy urengoy
# Processing Record 46 of Set 11 | portland
# Processing Record 47 of Set 11 | tyup
# Processing Record 48 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 11 | loiza
# Processing Record 50 of Set 11 | port-cartier
# Processing Record 1 of Set 12 | waipawa
# Processing Record 2 of Set 12 | dondo
# Processing Record 3 of Set 12 | bria
# Processing Record 4 of Set 12 | sibu
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | alcaniz
# Processing Record 7 of Set 12 | soe
# Processing Record 8 of Set 12 | saint george
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | san cristobal
# Processing Record 11 of Set 12 | veraval
# Processing Record 12 of Set 12 | aldan
# Processing Record 13 of Set 12 | khandyga
# Processing Record 14 of Set 12 | constantine
# Processing Record 15 of Set 12 | panormos
# Processing Record 16 of Set 12 | gat
# Processing Record 17 of Set 12 | ketchikan
# Processing Record 18 of Set 12 | tazlar
# Processing Record 19 of Set 12 | coari
# Processing Record 20 of Set 12 | berlevag
# Processing Record 21 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | cayenne
# Processing Record 23 of Set 12 | phek
# Processing Record 24 of Set 12 | vung tau
# Processing Record 25 of Set 12 | valparaiso
# Processing Record 26 of Set 12 | roald
# Processing Record 27 of Set 12 | lahij
# Processing Record 28 of Set 12 | juliaca
# Processing Record 29 of Set 12 | qui nhon
# Processing Record 30 of Set 12 | pran buri
# Processing Record 31 of Set 12 | kaliua
# Processing Record 32 of Set 12 | comodoro rivadavia
# Processing Record 33 of Set 12 | timiryazevskoye
# Processing Record 34 of Set 12 | lac du bonnet
# Processing Record 35 of Set 12 | kundian
# Processing Record 36 of Set 12 | la palma
# Processing Record 37 of Set 12 | ovre ardal
# Processing Record 38 of Set 12 | millinocket
# Processing Record 39 of Set 12 | viedma
# Processing Record 40 of Set 12 | isangel
# Processing Record 41 of Set 12 | villaviciosa
# Processing Record 42 of Set 12 | victoria
# Processing Record 43 of Set 12 | tilichiki
# Processing Record 44 of Set 12 | port moresby
# Processing Record 45 of Set 12 | sioux lookout
# Processing Record 46 of Set 12 | coyaima
# Processing Record 47 of Set 12 | krasnoselkup
# Processing Record 48 of Set 12 | evensk
# Processing Record 49 of Set 12 | port-gentil
# Processing Record 50 of Set 12 | cabedelo
# Processing Record 1 of Set 13 | dmitriyevka
# Processing Record 2 of Set 13 | zeya
# Processing Record 3 of Set 13 | beoumi
# Processing Record 4 of Set 13 | hofn
# Processing Record 5 of Set 13 | nanortalik
# Processing Record 6 of Set 13 | tonstad
# Processing Record 7 of Set 13 | beihai
# Processing Record 8 of Set 13 | gamba
# Processing Record 9 of Set 13 | tacoronte
# Processing Record 10 of Set 13 | san juan
# Processing Record 11 of Set 13 | pitimbu
# Processing Record 12 of Set 13 | linhares
# Processing Record 13 of Set 13 | puli
# Processing Record 14 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 15 of Set 13 | bajil
# Processing Record 16 of Set 13 | baculin
# Processing Record 17 of Set 13 | kupino
# Processing Record 18 of Set 13 | ribas do rio pardo
# Processing Record 19 of Set 13 | fairbanks
# Processing Record 20 of Set 13 | ambulu
# Processing Record 21 of Set 13 | katsuura
# Processing Record 22 of Set 13 | boden
# Processing Record 23 of Set 13 | dire
# Processing Record 24 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 25 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 13 | maarianhamina
# Processing Record 27 of Set 13 | san jeronimo
# Processing Record 28 of Set 13 | kununurra
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | shatki
# Processing Record 31 of Set 13 | machado
# Processing Record 32 of Set 13 | faenza
# Processing Record 33 of Set 13 | the valley
# Processing Record 34 of Set 13 | soubre
# Processing Record 35 of Set 13 | samarai
# Processing Record 36 of Set 13 | kiama
# Processing Record 37 of Set 13 | boguchany
# Processing Record 38 of Set 13 | bilibino
# Processing Record 39 of Set 13 | mahon
# Processing Record 40 of Set 13 | polyarnyy
# Processing Record 41 of Set 13 | trebinje
# Processing Record 42 of Set 13 | cabanas
# Processing Record 43 of Set 13 | danbury
# Processing Record 44 of Set 13 | saint-augustin
# Processing Record 45 of Set 13 | burnie
# Processing Record 46 of Set 13 | san vicente
# Processing Record 47 of Set 13 | mpulungu
# Processing Record 48 of Set 13 | dharchula
# Processing Record 49 of Set 13 | fukue
# Processing Record 50 of Set 13 | tiznit
# Processing Record 1 of Set 14 | mbandaka
# Processing Record 2 of Set 14 | tessalit
# Processing Record 3 of Set 14 | san quintin
# Processing Record 4 of Set 14 | dong hoi
# Processing Record 5 of Set 14 | martapura
# Processing Record 6 of Set 14 | tatarsk
# Processing Record 7 of Set 14 | palafrugell
# Processing Record 8 of Set 14 | turukhansk
# Processing Record 9 of Set 14 | novokizhinginsk
# Processing Record 10 of Set 14 | la crosse
# Processing Record 11 of Set 14 | manjeshwar
# Processing Record 12 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 14 | awjilah
# Processing Record 14 of Set 14 | madang
# Processing Record 15 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 14 | ogdensburg
# Processing Record 17 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 14 | jacksonville
# Processing Record 19 of Set 14 | borskoye
# Processing Record 20 of Set 14 | mayor pablo lagerenza
# Processing Record 21 of Set 14 | mopipi
# Processing Record 22 of Set 14 | hulan ergi
# Processing Record 23 of Set 14 | alyangula
# Processing Record 24 of Set 14 | craig
# Processing Record 25 of Set 14 | mongoumba
# Processing Record 26 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 14 | foix
# Processing Record 28 of Set 14 | wanlaweyn
# Processing Record 29 of Set 14 | long branch
# Processing Record 30 of Set 14 | skibbereen
# Processing Record 31 of Set 14 | athabasca
# Processing Record 32 of Set 14 | rio branco
# Processing Record 33 of Set 14 | kuusamo
# Processing Record 34 of Set 14 | ulladulla
# Processing Record 35 of Set 14 | winslow
# Processing Record 36 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 14 | kualakapuas
# Processing Record 39 of Set 14 | urumqi
# Processing Record 40 of Set 14 | chifeng
# Processing Record 41 of Set 14 | kuching
# Processing Record 42 of Set 14 | eskilstuna
# Processing Record 43 of Set 14 | asyut
# Processing Record 44 of Set 14 | tombouctou
# Processing Record 45 of Set 14 | roebourne
# Processing Record 46 of Set 14 | luwuk
# Processing Record 47 of Set 14 | galesong
# Processing Record 48 of Set 14 | bumba
# Processing Record 49 of Set 14 | arrecife
# Processing Record 50 of Set 14 | otavi
# Processing Record 1 of Set 15 | sire
# Processing Record 2 of Set 15 | ruteng
# Processing Record 3 of Set 15 | marsh harbour
# Processing Record 4 of Set 15 | vinstra
# Processing Record 5 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 15 | san ramon
# Processing Record 7 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 8 of Set 15 | simao
# Processing Record 9 of Set 15 | alamos
# Processing Record 10 of Set 15 | moundsville
# Processing Record 11 of Set 15 | sibolga
# Processing Record 12 of Set 15 | trat
# Processing Record 13 of Set 15 | klaksvik
# Processing Record 14 of Set 15 | salina cruz
# Processing Record 15 of Set 15 | westport
# Processing Record 16 of Set 15 | cimislia
# Processing Record 17 of Set 15 | kargopol
# Processing Record 18 of Set 15 | pitiquito
# Processing Record 19 of Set 15 | terney
# Processing Record 20 of Set 15 | almaty
# Processing Record 21 of Set 15 | sangar
# Processing Record 22 of Set 15 | okhotsk
# Processing Record 23 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 15 | olafsvik
# Processing Record 25 of Set 15 | tyumentsevo
# Processing Record 26 of Set 15 | kawambwa
# Processing Record 27 of Set 15 | kud
# Processing Record 28 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 15 | tongliao
# Processing Record 30 of Set 15 | areka
# Processing Record 31 of Set 15 | butia
# Processing Record 32 of Set 15 | rio grande
# Processing Record 33 of Set 15 | turinsk
# Processing Record 34 of Set 15 | obo
# Processing Record 35 of Set 15 | atocha
# Processing Record 36 of Set 15 | arman
# Processing Record 37 of Set 15 | goma
# Processing Record 38 of Set 15 | paramirim
# Processing Record 39 of Set 15 | yulara
# Processing Record 40 of Set 15 | muroto
# Processing Record 41 of Set 15 | navirai
# Processing Record 42 of Set 15 | berdigestyakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Filotion      GR  37.0500   25.5000     51.80        82          80
# 1  Punta Arenas      CL -53.1500  -70.9167     50.00        71           0
# 2         Vaini      TO -21.2000 -175.2000     77.00        94          75
# 3  Coolum Beach      AU -26.5333  153.1000     62.01        96          68
# 4     Hay River      CA  60.8156 -115.7999     32.00        64         100
# 5     Busselton      AU -33.6500  115.3333     66.00        91         100
# 6          Nome      US  64.5011 -165.4064     -7.60        77           1
# 7        Hobart      AU -42.8794  147.3294     66.20        63          86
# 8       Mataura      NZ -46.1927  168.8643     37.99        93          19
# 9     Cape Town      ZA -33.9258   18.4232     66.00        77          75
#
#    Wind Speed Current Description
# 0       23.02       broken clouds
# 1        6.91           clear sky
# 2        5.75          light rain
# 3        1.01       broken clouds
# 4        5.75          light snow
# 5        4.00       moderate rain
# 6        6.24           clear sky
# 7       10.36     overcast clouds
# 8        1.01          few clouds
# 9        4.61       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
